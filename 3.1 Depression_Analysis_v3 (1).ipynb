# %%
#install libraries
# !pip install bnlp
# !pip install bnlp_toolkit
# !pip install --upgrade bnlp_toolkit
# Out:
# Collecting bnlp
#   Downloading bnlp-0.8.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bnlp
#   Building wheel for bnlp (setup.py) ... done
#   Created wheel for bnlp: filename=bnlp-0.8-py3-none-any.whl size=32802 sha256=da9f4190a20a17019d9221c0fd4d6fe55903f06c23388d56edfdfab183a017b1
#   Stored in directory: /root/.cache/pip/wheels/64/c7/7e/272284eb8c800fbb5306bdf7904ae9f99a64812fc615f471b2
# Successfully built bnlp
# Installing collected packages: bnlp
# Successfully installed bnlp-0.8
# Collecting bnlp_toolkit
#   Downloading bnlp_toolkit-4.0.3-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: sentencepiece==0.2.0 in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (0.2.0)
# Collecting gensim==4.3.2 (from bnlp_toolkit)
#   Downloading gensim-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (1.26.4)
# Collecting scipy==1.10.1 (from bnlp_toolkit)
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.3 MB/s eta 0:00:00
# Collecting sklearn-crfsuite==0.3.6 (from bnlp_toolkit)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting tqdm==4.66.3 (from bnlp_toolkit)
#   Downloading tqdm-4.66.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.9 MB/s eta 0:00:00
# Collecting ftfy==6.2.0 (from bnlp_toolkit)
#   Downloading ftfy-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting emoji==1.7.0 (from bnlp_toolkit)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 16.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (2.32.3)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.2.0->bnlp_toolkit) (0.2.13)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim==4.3.2->bnlp_toolkit) (7.0.5)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite==0.3.6->bnlp_toolkit)
#   Downloading python_crfsuite-0.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite==0.3.6->bnlp_toolkit) (1.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite==0.3.6->bnlp_toolkit) (0.9.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp_toolkit) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp_toolkit) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp_toolkit) (2024.9.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (2024.8.30)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim==4.3.2->bnlp_toolkit) (1.16.0)
# Downloading bnlp_toolkit-4.0.3-py3-none-any.whl (22 kB)
# Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 6.4 MB/s eta 0:00:00
# Downloading gensim-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 21.3 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 25.9 MB/s eta 0:00:00
# Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Downloading tqdm-4.66.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.6 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.2 MB/s eta 0:00:00
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=52b048fba79d89f2734bc804f6348ae1781c3ae6ee260d70428e2c044e6393bf
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# Installing collected packages: emoji, tqdm, scipy, python-crfsuite, ftfy, sklearn-crfsuite, gensim, bnlp_toolkit
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.6
#     Uninstalling tqdm-4.66.6:
#       Successfully uninstalled tqdm-4.66.6
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.3
#     Uninstalling gensim-4.3.3:
#       Successfully uninstalled gensim-4.3.3
# Successfully installed bnlp_toolkit-4.0.3 emoji-1.7.0 ftfy-6.2.0 gensim-4.3.2 python-crfsuite-0.9.11 scipy-1.10.1 sklearn-crfsuite-0.3.6 tqdm-4.66.3
# Requirement already satisfied: bnlp_toolkit in /usr/local/lib/python3.10/dist-packages (4.0.3)
# Requirement already satisfied: sentencepiece==0.2.0 in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (0.2.0)
# Requirement already satisfied: gensim==4.3.2 in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (4.3.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (1.26.4)
# Requirement already satisfied: scipy==1.10.1 in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (1.10.1)
# Requirement already satisfied: sklearn-crfsuite==0.3.6 in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (0.3.6)
# Requirement already satisfied: tqdm==4.66.3 in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (4.66.3)
# Requirement already satisfied: ftfy==6.2.0 in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (6.2.0)
# Requirement already satisfied: emoji==1.7.0 in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (1.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (2.32.3)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.2.0->bnlp_toolkit) (0.2.13)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim==4.3.2->bnlp_toolkit) (7.0.5)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite==0.3.6->bnlp_toolkit) (0.9.11)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite==0.3.6->bnlp_toolkit) (1.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite==0.3.6->bnlp_toolkit) (0.9.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp_toolkit) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp_toolkit) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp_toolkit) (2024.9.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (2024.8.30)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim==4.3.2->bnlp_toolkit) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Install necessary dependencies
# !pip install bnlp3
import nltk
nltk.download('stopwords')  # Download stopwords

try:
    # Attempt to use stopwords from bnlp3 if available
    from bnlp.corpus import stopwords
    stopwords_list = stopwords()
    print("Using stopwords from bnlp3.")
except ImportError:
    # If bnlp3 does not have stopwords, use nltk as a fallback
    from nltk.corpus import stopwords
    stopwords_list = set(stopwords.words('bengali'))
    print("Using Bangla stopwords from nltk.")

# Display the list of Bangla stopwords
print(stopwords_list)
# Out:
# Requirement already satisfied: bnlp3 in /usr/local/lib/python3.10/dist-packages (0.7)
# Using Bangla stopwords from nltk.
# {'হলো', 'হৈলে', 'তাঁর', 'হওয়া', 'অনেকে', 'কয়েকটি', 'ছিলেন', 'এখন', 'হলেই', 'আরও', 'মনে', 'ব্যবহার', 'নাই', 'রয়েছে', 'লক্ষ', 'হয়নি', 'হয়ে', 'একে', 'এটি', 'শুরু', 'পর', 'নয়', 'হিসাবে', 'উত্তর', 'কোনো', 'এমন', 'হোক', 'বসে', 'হয়েছিল', 'দেওয়া', 'পি', 'এখনও', 'এবং', 'বন', 'সমস্ত', 'চায়', 'যাকে', 'এস', 'উপরে', 'ঠিক', 'করি', 'পরেও', 'পারে', 'তাঁাহারা', 'এর', 'কিংবা', 'এবার', 'বি', 'তথা', 'থাকে', 'দিয়েছেন', 'জানতে', 'কিন্তু', 'হইবে', 'বক্তব্য', 'থেকেও', 'আবার', 'মাত্র', 'প্রতি', 'পরে', 'তারা', 'তাই', 'কেউই', 'গিয়ে', 'জানা', 'হতে', 'ধামার', 'তাহা', 'সেই', 'অর্থাত', 'থেকেই', 'এ', 'দিয়েছে', 'আগে', 'করেছেন', 'বাদে', 'কয়েক', 'এরা', 'শুধু', 'বহু', 'বলেন', 'আপনার', 'সেটাই', 'রকম', 'পাচ', 'ব্যাপারে', 'বলল', 'চার', 'কিছুই', 'যদিও', 'ধরা', 'কেখা', 'তবু', 'হচ্ছে', 'এখানে', 'প্রথম', 'উচিত', 'এক্', 'দেন', 'র', 'তিনি', 'জানায়', 'ফের', 'এব', 'অনেকেই', 'গিয়েছে', 'যাওয়া', 'দুটো', 'তাকে', 'বিনা', 'এতটাই', 'জনের', 'একই', 'আমরা', 'অবধি', 'এমনি', 'অন্য', 'এঁদের', 'নিজের', 'যা', 'প্রায়', 'জানানো', 'এঁরা', 'থাকবে', 'হতেই', 'পক্ষে', 'অন্তত', 'জন্য', 'মধ্যভাগে', 'নিয়ে', 'দিতে', 'কেউ', 'ভাবে', 'নতুন', 'এমনকী', 'সবার', 'অথবা', 'গিয়ে', 'দেখতে', 'কি', 'আদ্যভাগে', 'হবেন', 'কয়েক', 'অথচ', 'মাধ্যমে', 'কত', 'থাকবেন', 'আমাকে', 'দেওয়ার', 'আপনি', 'ক্ষেত্রে', 'ইহা', 'দুই', 'করায়', 'নয়', 'করেছিলেন', 'খুব', 'চেষ্টা', 'যাঁর', 'কেন', 'যাতে', 'ছিল', 'তোমার', 'কোনও', 'নেওয়ার', 'আগেই', 'করিয়ে', 'একবার', 'করলে', 'নিজেই', 'যেখানে', 'সব', 'যখন', 'যার', 'কাজ', 'থাকেন', 'আমাদের', 'ওই', 'কারও', 'স্পষ্ট', 'ওঁরা', 'করিয়া', 'যাঁরা', 'কমনে', 'গেলে', 'তার', 'বলে', 'সম্প্রতি', 'এটাই', 'করবেন', 'তখন', 'দিন', 'থেকে', 'পাওয়া', 'বিভিন্ন', 'ধরে', 'সুতরাং', 'ওরা', 'ঐ', 'করছে', 'করেই', 'তাও', 'যাচ্ছে', 'মোটেই', 'গেছে', 'ও', 'করেছে', 'দেখে', 'যতটা', 'যাওয়া', 'গুলি', 'জানিয়ে', 'তারৈ', 'কখনও', 'মধ্যেই', 'সঙ্গেও', 'যথেষ্ট', 'একটি', 'হবে', 'পরেই', 'বেশ', 'সাধারণ', 'যায়', 'করিতে', 'আমি', 'কোটি', 'বললেন', 'বদলে', 'চলে', 'দিয়ে', 'যাদের', 'তুমি', 'বিশেষ', 'দু', 'অবশ্য', 'পর্যন্ত', 'ইত্যাদি', 'যেতে', 'যান', 'করার', 'হলে', 'যিনি', 'অনুযায়ী', 'হইতে', 'করবে', 'ছাড়া', 'হল', 'জনকে', 'আগামী', 'যারা', 'কাছে', 'গেল', 'হলেও', 'বলা', 'বেশি', 'ওদের', 'প্রায়', 'বরং', 'এতে', 'নাকি', 'আই', 'দেয়', 'যত', 'এখানেই', 'তাহাতে', 'করছেন', 'ফিরে', 'দেওয়া', 'কে', 'সেখান', 'যাওয়ার', 'তাহার', 'দিকে', 'নানা', 'ওঁদের', 'মধ্যেও', 'হন', 'নিয়ে', 'নিজে', 'ওঁর', 'ওর', 'কোন', 'তারপর', 'দুটি', 'রেখে', 'কাউকে', 'পারেন', 'হাজার', 'হয়তো', 'আজ', 'তাহলে', 'হওয়ার', 'থাকায়', 'নিজেদের', 'হয়', 'পেয়্র্', 'ছাড়াও', 'এদের', 'এল', 'ওকে', 'নেওয়া', 'সামনে', 'ওখানে', 'গোটা', 'রাখা', 'টি', 'হওয়ায়', 'অতএব', 'দিলেন', 'মোট', 'হত', 'অনেক', 'না', 'কাজে', 'কবে', 'করাই', 'নেই', 'চেয়ে', 'করা', 'কী', 'কাছ', 'তাঁরা', 'সি', 'তুলে', 'সেটা', 'পারি', 'মতো', 'সহিত', 'নিতে', 'বলতে', 'সে', 'তাদের', 'জানিয়েছে', 'তো', 'প্রযন্ত', 'কিছু', 'আর', 'জে', 'জন', 'করেন', 'সহ', 'হয়েছেন', 'এসে', 'বার', 'সেটাও', 'যেন', 'আমার', 'দ্বারা', 'করে', 'যাবে', 'ই', 'তা', 'বা', 'তিনিও', 'হয়েছে', 'বলেছেন', 'তবে', 'তত', 'হয়েই', 'প্রাথমিক', 'এটা', 'তাতে', 'এত', 'সঙ্গে', 'আছে', 'তাঁকে', 'উনি', 'হইয়া', 'চালু', 'জন্যওজে', 'বিষয়টি', 'প্রভৃতি', 'তিনঐ', 'সেখানে', 'করতে', 'থাকা', 'যদি', 'যেমন', 'মধ্যে', 'মতোই', 'তাঁদের', 'দেখা', 'পেয়ে', 'উপর', 'নাগাদ', 'নেওয়া', 'চান', 'কারণ', 'সেটি', 'স্বয়ং', 'ফলে', 'ভাবেই', 'এই', 'যে', 'তেমন', 'করলেন', 'জ্নজন', 'হয়'}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Import libraries
import numpy as np
import pandas as pd
import random
import re, string
import seaborn as sns
import matplotlib.pyplot as plt

from string import punctuation
from bnlp import BasicTokenizer, NLTKTokenizer, SentencepieceTokenizer
from bnlp import BengaliWord2Vec

# Set style for plots
sns.set_style("whitegrid")
plt.style.use("ggplot")  # Changed to "ggplot" for compatibility
plt.rc("figure", autolayout=True)
plt.rc("axes", labelweight="bold", labelsize="large", titleweight="bold", titlepad=10)

# Verify available styles (optional)
print("Available styles:", plt.style.available)

# Data preprocessing
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

# Naive Bayes
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

# PyTorch LSTM
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

# Tokenization for LSTM
from collections import Counter
from gensim.models import Word2Vec, FastText

# Metrics and evaluation
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
# Out:
# Available styles: ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Define Performance Metrics & Confusion Matrix

# %%
# Calculate performance metrics
def perf_matrix(y_test, y_pred):
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred, average='weighted')
  recall = recall_score(y_test, y_pred, average='weighted')
  f1 = f1_score(y_test, y_pred, average='weighted')

  print('Accuracy:', accuracy)
  print('Precision:', precision)
  print('Recall:', recall)
  print('F1 Score:', f1)

# Plot confusion matrix
def conf_matrix(y_test, y_pred, title, labels):
    fig, ax =plt.subplots(figsize=(4,4))
    ax=sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cmap="Greens", fmt='g', cbar=True, annot_kws={"size":20})
    plt.title(title, fontsize=25)
    ax.xaxis.set_ticklabels(labels, fontsize=16)
    ax.yaxis.set_ticklabels(labels, fontsize=14.5)
    ax.set_ylabel('Test', fontsize=25)
    ax.set_xlabel('Predicted', fontsize=25)
    plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/NLP Project/Code/
# Out:
# [Errno 20] Not a directory: '/content/drive/MyDrive/nlp project dataset/BSMDD_v3_textcleaned - 21K.xlsx'
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
df = pd.read_excel('/content/drive/MyDrive/nlp project dataset/BSMDD_v3_textcleaned - 21K.xlsx')

print(df.info())
print("")
print(df.label.value_counts())
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21910 entries, 0 to 21909
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    21910 non-null  object
#  1   label   21910 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 342.5+ KB
# None
#
# label
# 1    10961
# 0    10949
# Name: count, dtype: int64
#                                                 text  label
# 0  মানসিক শারীরিকভাবে অসুস্থ ক্লান্ত পুরো জীবন শা...      1
# 1  দয়া সাথে থাকুন অত্যন্ত দীর্ঘ আপনাকে পড়তে উত্...      1
# 2  জানতাম সাথে ভুল লোক খারাপ জীবন কাটিয়েছে সম্পূ...      1
# 3  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 4  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 5  প্রথমে আপনাকে প্রশ্ন উপস্থাপন যাচ্ছি পারবেন দি...      1
# 6  রেফারেন্সের বয়সী পুরুষ থাকার সাইক ওয়ার্ড বের...      1
# 7  দৈর্ঘ্যের ক্ষমাপ্রার্থী বোঝানোর বের আলিঙ্গন বল...      1
# 8  উপকারী সাব দয়া আপলোড পোস্ট সেরা জায়গা মোবাইল...      1
# 9  দীর্ঘ পোস্ট জীবনের সারসংক্ষেপ টাইম লাইনটি একটু...      1

# %% [markdown]
# # Data Cleaning

# %%
# Drop rows with any missing values
df = df.dropna(subset=['text', 'label'])
# drop rows that have identical values in all columns
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21904 entries, 0 to 21909
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    21904 non-null  object
#  1   label   21904 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 513.4+ KB

# %%
# Import stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Bengali stopwords
bengali_stopwords = set(stopwords.words('bengali'))

# Bengali punctuations (you can adjust this list as needed)
punctuations = list("।.,?!:;—()[]{}<>\"'`’“”…")

# Bengali letters (Unicode range for Bengali characters)
letters = [chr(i) for i in range(0x0980, 0x09FF + 1)]

# Bengali digits (Unicode range for Bengali digits)
digits = [chr(i) for i in range(0x09E6, 0x09EF + 1)]

# Display Bengali stopwords, punctuation, letters, and digits
print("Bengali Stopwords:", bengali_stopwords)
print("Bengali Punctuations:", punctuations)
print("Bengali Letters:", letters)
print("Bengali Digits:", digits)
# Out:
# Bengali Stopwords: {'হলো', 'হৈলে', 'তাঁর', 'হওয়া', 'অনেকে', 'কয়েকটি', 'ছিলেন', 'এখন', 'হলেই', 'আরও', 'মনে', 'ব্যবহার', 'নাই', 'রয়েছে', 'লক্ষ', 'হয়নি', 'হয়ে', 'একে', 'এটি', 'শুরু', 'পর', 'নয়', 'হিসাবে', 'উত্তর', 'কোনো', 'এমন', 'হোক', 'বসে', 'হয়েছিল', 'দেওয়া', 'পি', 'এখনও', 'এবং', 'বন', 'সমস্ত', 'চায়', 'যাকে', 'এস', 'উপরে', 'ঠিক', 'করি', 'পরেও', 'পারে', 'তাঁাহারা', 'এর', 'কিংবা', 'এবার', 'বি', 'তথা', 'থাকে', 'দিয়েছেন', 'জানতে', 'কিন্তু', 'হইবে', 'বক্তব্য', 'থেকেও', 'আবার', 'মাত্র', 'প্রতি', 'পরে', 'তারা', 'তাই', 'কেউই', 'গিয়ে', 'জানা', 'হতে', 'ধামার', 'তাহা', 'সেই', 'অর্থাত', 'থেকেই', 'এ', 'দিয়েছে', 'আগে', 'করেছেন', 'বাদে', 'কয়েক', 'এরা', 'শুধু', 'বহু', 'বলেন', 'আপনার', 'সেটাই', 'রকম', 'পাচ', 'ব্যাপারে', 'বলল', 'চার', 'কিছুই', 'যদিও', 'ধরা', 'কেখা', 'তবু', 'হচ্ছে', 'এখানে', 'প্রথম', 'উচিত', 'এক্', 'দেন', 'র', 'তিনি', 'জানায়', 'ফের', 'এব', 'অনেকেই', 'গিয়েছে', 'যাওয়া', 'দুটো', 'তাকে', 'বিনা', 'এতটাই', 'জনের', 'একই', 'আমরা', 'অবধি', 'এমনি', 'অন্য', 'এঁদের', 'নিজের', 'যা', 'প্রায়', 'জানানো', 'এঁরা', 'থাকবে', 'হতেই', 'পক্ষে', 'অন্তত', 'জন্য', 'মধ্যভাগে', 'নিয়ে', 'দিতে', 'কেউ', 'ভাবে', 'নতুন', 'এমনকী', 'সবার', 'অথবা', 'গিয়ে', 'দেখতে', 'কি', 'আদ্যভাগে', 'হবেন', 'কয়েক', 'অথচ', 'মাধ্যমে', 'কত', 'থাকবেন', 'আমাকে', 'দেওয়ার', 'আপনি', 'ক্ষেত্রে', 'ইহা', 'দুই', 'করায়', 'নয়', 'করেছিলেন', 'খুব', 'চেষ্টা', 'যাঁর', 'কেন', 'যাতে', 'ছিল', 'তোমার', 'কোনও', 'নেওয়ার', 'আগেই', 'করিয়ে', 'একবার', 'করলে', 'নিজেই', 'যেখানে', 'সব', 'যখন', 'যার', 'কাজ', 'থাকেন', 'আমাদের', 'ওই', 'কারও', 'স্পষ্ট', 'ওঁরা', 'করিয়া', 'যাঁরা', 'কমনে', 'গেলে', 'তার', 'বলে', 'সম্প্রতি', 'এটাই', 'করবেন', 'তখন', 'দিন', 'থেকে', 'পাওয়া', 'বিভিন্ন', 'ধরে', 'সুতরাং', 'ওরা', 'ঐ', 'করছে', 'করেই', 'তাও', 'যাচ্ছে', 'মোটেই', 'গেছে', 'ও', 'করেছে', 'দেখে', 'যতটা', 'যাওয়া', 'গুলি', 'জানিয়ে', 'তারৈ', 'কখনও', 'মধ্যেই', 'সঙ্গেও', 'যথেষ্ট', 'একটি', 'হবে', 'পরেই', 'বেশ', 'সাধারণ', 'যায়', 'করিতে', 'আমি', 'কোটি', 'বললেন', 'বদলে', 'চলে', 'দিয়ে', 'যাদের', 'তুমি', 'বিশেষ', 'দু', 'অবশ্য', 'পর্যন্ত', 'ইত্যাদি', 'যেতে', 'যান', 'করার', 'হলে', 'যিনি', 'অনুযায়ী', 'হইতে', 'করবে', 'ছাড়া', 'হল', 'জনকে', 'আগামী', 'যারা', 'কাছে', 'গেল', 'হলেও', 'বলা', 'বেশি', 'ওদের', 'প্রায়', 'বরং', 'এতে', 'নাকি', 'আই', 'দেয়', 'যত', 'এখানেই', 'তাহাতে', 'করছেন', 'ফিরে', 'দেওয়া', 'কে', 'সেখান', 'যাওয়ার', 'তাহার', 'দিকে', 'নানা', 'ওঁদের', 'মধ্যেও', 'হন', 'নিয়ে', 'নিজে', 'ওঁর', 'ওর', 'কোন', 'তারপর', 'দুটি', 'রেখে', 'কাউকে', 'পারেন', 'হাজার', 'হয়তো', 'আজ', 'তাহলে', 'হওয়ার', 'থাকায়', 'নিজেদের', 'হয়', 'পেয়্র্', 'ছাড়াও', 'এদের', 'এল', 'ওকে', 'নেওয়া', 'সামনে', 'ওখানে', 'গোটা', 'রাখা', 'টি', 'হওয়ায়', 'অতএব', 'দিলেন', 'মোট', 'হত', 'অনেক', 'না', 'কাজে', 'কবে', 'করাই', 'নেই', 'চেয়ে', 'করা', 'কী', 'কাছ', 'তাঁরা', 'সি', 'তুলে', 'সেটা', 'পারি', 'মতো', 'সহিত', 'নিতে', 'বলতে', 'সে', 'তাদের', 'জানিয়েছে', 'তো', 'প্রযন্ত', 'কিছু', 'আর', 'জে', 'জন', 'করেন', 'সহ', 'হয়েছেন', 'এসে', 'বার', 'সেটাও', 'যেন', 'আমার', 'দ্বারা', 'করে', 'যাবে', 'ই', 'তা', 'বা', 'তিনিও', 'হয়েছে', 'বলেছেন', 'তবে', 'তত', 'হয়েই', 'প্রাথমিক', 'এটা', 'তাতে', 'এত', 'সঙ্গে', 'আছে', 'তাঁকে', 'উনি', 'হইয়া', 'চালু', 'জন্যওজে', 'বিষয়টি', 'প্রভৃতি', 'তিনঐ', 'সেখানে', 'করতে', 'থাকা', 'যদি', 'যেমন', 'মধ্যে', 'মতোই', 'তাঁদের', 'দেখা', 'পেয়ে', 'উপর', 'নাগাদ', 'নেওয়া', 'চান', 'কারণ', 'সেটি', 'স্বয়ং', 'ফলে', 'ভাবেই', 'এই', 'যে', 'তেমন', 'করলেন', 'জ্নজন', 'হয়'}
# Bengali Punctuations: ['।', '.', ',', '?', '!', ':', ';', '—', '(', ')', '[', ']', '{', '}', '<', '>', '"', "'", '`', '’', '“', '”', '…']
# Bengali Letters: ['ঀ', 'ঁ', 'ং', 'ঃ', '\u0984', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ', 'ঋ', 'ঌ', '\u098d', '\u098e', 'এ', 'ঐ', '\u0991', '\u0992', 'ও', 'ঔ', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', '\u09a9', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', '\u09b1', 'ল', '\u09b3', '\u09b4', '\u09b5', 'শ', 'ষ', 'স', 'হ', '\u09ba', '\u09bb', '়', 'ঽ', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ৄ', '\u09c5', '\u09c6', 'ে', 'ৈ', '\u09c9', '\u09ca', 'ো', 'ৌ', '্', 'ৎ', '\u09cf', '\u09d0', '\u09d1', '\u09d2', '\u09d3', '\u09d4', '\u09d5', '\u09d6', 'ৗ', '\u09d8', '\u09d9', '\u09da', '\u09db', 'ড়', 'ঢ়', '\u09de', 'য়', 'ৠ', 'ৡ', 'ৢ', 'ৣ', '\u09e4', '\u09e5', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯', 'ৰ', 'ৱ', '৲', '৳', '৴', '৵', '৶', '৷', '৸', '৹', '৺', '৻', 'ৼ', '৽', '৾', '\u09ff']
# Bengali Digits: ['০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Define the list of Bangla punctuations, digits
deleted_list = list(punctuation) + list(digits) + ['|', '‘', '’','।','।', '...', '``', '/''','ã','¢','ƒ','¡','ª','‚','«','ç','§','¯','®','å','â','œ','›','½','æ','†','€','α','ž','β','γ','â€','ð','Ÿ','˜','','¼','¦','³','°','¥','¿','¡','„','¶','´','‡','·','»','','››']
print(deleted_list)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯', '|', '‘', '’', '।', '।', '...', '``', '/', 'ã', '¢', 'ƒ', '¡', 'ª', '‚', '«', 'ç', '§', '¯', '®', 'å', 'â', 'œ', '›', '½', 'æ', '†', '€', 'α', 'ž', 'β', 'γ', 'â€', 'ð', 'Ÿ', '˜', '\x90', '¼', '¦', '³', '°', '¥', '¿', '¡', '„', '¶', '´', '‡', '·', '»', '', '››']

# %%
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Initialize the tokenizer
tokenizer = word_tokenize

# Define stopwords for Bengali
bengali_stopwords = set(stopwords.words('bengali'))

# Define a list of punctuation characters (can adjust as needed)
punctuation = list(string.punctuation)

# Define any additional words to be removed
deleted_list = []  # Populate this with any specific words you want to remove

# Define a function to preprocess the text data
def preprocess_text(text):
    # Remove HTML tags
    text = re.sub('<[^>]*>', '', text)
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    # Remove \n and \r and lowercase
    text = text.replace('\r', '').replace('\n', ' ').lower()
    # Remove links and mentions
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    # Remove English characters and numbers
    text = re.sub(r'[a-zA-Z0-9]+', '', text)
    # Remove irrelevant characters (if needed)
    text = re.sub(r'[Α-Ωα-ω]+', '', text)

    # Remove punctuation
    banned_list = string.punctuation
    table = str.maketrans('', '', banned_list)
    text = text.translate(table)

    # Tokenize the text data
    tokens = tokenizer(text)
    # Remove stopwords and punctuations
    tokens = [w.lower() for w in tokens if w.lower() not in bengali_stopwords and w not in deleted_list and w not in punctuation and not w.isnumeric() and not w.isalpha()]
    # Join the tokens back to form a string
    processed = ' '.join(tokens)
    return processed

# Assuming df is your DataFrame with a 'text' column
texts_new = []
for t in df['text']:
    texts_new.append(preprocess_text(t))

df['text_clean'] = texts_new

# %%
print(df.info())
print("")
print(df.label.value_counts())
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21904 entries, 0 to 21909
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        21904 non-null  object
#  1   label       21904 non-null  int64
#  2   text_clean  21904 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 684.5+ KB
# None
#
# label
# 1    10957
# 0    10947
# Name: count, dtype: int64
#                                                 text  label  \
# 0  মানসিক শারীরিকভাবে অসুস্থ ক্লান্ত পুরো জীবন শা...      1
# 1  দয়া সাথে থাকুন অত্যন্ত দীর্ঘ আপনাকে পড়তে উত্...      1
# 2  জানতাম সাথে ভুল লোক খারাপ জীবন কাটিয়েছে সম্পূ...      1
# 3  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 4  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 5  প্রথমে আপনাকে প্রশ্ন উপস্থাপন যাচ্ছি পারবেন দি...      1
# 6  রেফারেন্সের বয়সী পুরুষ থাকার সাইক ওয়ার্ড বের...      1
# 7  দৈর্ঘ্যের ক্ষমাপ্রার্থী বোঝানোর বের আলিঙ্গন বল...      1
# 8  উপকারী সাব দয়া আপলোড পোস্ট সেরা জায়গা মোবাইল...      1
# 9  দীর্ঘ পোস্ট জীবনের সারসংক্ষেপ টাইম লাইনটি একটু...      1
#
#                                           text_clean
# 0  মানসিক শারীরিকভাবে অসুস্থ ক্লান্ত পুরো জীবন শা...
# 1  দয়া সাথে থাকুন অত্যন্ত দীর্ঘ আপনাকে পড়তে উত্...
# 2  জানতাম সাথে ভুল লোক খারাপ জীবন কাটিয়েছে সম্পূ...
# 3  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...
# 4  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...
# 5  প্রথমে আপনাকে প্রশ্ন উপস্থাপন যাচ্ছি পারবেন দি...
# 6  রেফারেন্সের বয়সী পুরুষ থাকার সাইক ওয়ার্ড বের...
# 7  দৈর্ঘ্যের ক্ষমাপ্রার্থী বোঝানোর বের আলিঙ্গন বল...
# 8  উপকারী সাব দয়া আপলোড পোস্ট সেরা জায়গা মোবাইল...
# 9  দীর্ঘ পোস্ট জীবনের সারসংক্ষেপ টাইম লাইনটি একটু...

# %%
df['label'] = df['label'].replace({'Depressive': 1, 'Non Depressive': 0})

df['length_text'] = df['text'].apply(len)
df['length_text_clean'] = df['text_clean'].apply(len)

# Sort the dataframe by the 'length' column in descending order
df = df.sort_values(by='length_text_clean', ascending=False)
df
# Out:
#                                                     text  label  \
# 0      মানসিক শারীরিকভাবে অসুস্থ ক্লান্ত পুরো জীবন শা...      1
# 1      দয়া সাথে থাকুন অত্যন্ত দীর্ঘ আপনাকে পড়তে উত্...      1
# 2      জানতাম সাথে ভুল লোক খারাপ জীবন কাটিয়েছে সম্পূ...      1
# 3      অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 4      অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# ...                                                  ...    ...
# 21905                   কঠিন সময়ে আপনাকে বুদবুদ মোড়ানো      0
# 21906                    ডাঃ ছবি দেখেছেন সেউস কারো ধারণা      0
# 21907                     পুরুষ মুরগির আরেকটি শব্দ ” ¸ ¸      0
# 21908                     মুখ সত্যিই ভাল মেম সপ্তাহান্তে      0
# 21909                     অনুপ্রেরণামূলক টেক্সট ইমেজ ¸ ¸      0
#
#                                               text_clean  length_text  \
# 0      মানসিক শারীরিকভাবে অসুস্থ ক্লান্ত পুরো জীবন শা...         4904
# 1      দয়া সাথে থাকুন অত্যন্ত দীর্ঘ আপনাকে পড়তে উত্...         4655
# 2      জানতাম সাথে ভুল লোক খারাপ জীবন কাটিয়েছে সম্পূ...         4655
# 3      অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...         4607
# 4      অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...         4585
# ...                                                  ...          ...
# 21905                   কঠিন সময়ে আপনাকে বুদবুদ মোড়ানো           32
# 21906                    ডাঃ ছবি দেখেছেন সেউস কারো ধারণা           31
# 21907                     পুরুষ মুরগির আরেকটি শব্দ ” ¸ ¸           30
# 21908                     মুখ সত্যিই ভাল মেম সপ্তাহান্তে           30
# 21909                     অনুপ্রেরণামূলক টেক্সট ইমেজ ¸ ¸           30
#
#        length_text_clean
# 0                   4904
# 1                   4655
# 2                   4655
# 3                   4607
# 4                   4585
# ...                  ...
# 21905                 32
# 21906                 31
# 21907                 30
# 21908                 30
# 21909                 30
#
# [21904 rows x 5 columns]

# %%
# Filter the rows whose length is less than 30
filtered_df_min = df[df['length_text_clean'] < 30]

# Print the filtered data
print(len(filtered_df_min))
filtered_df_min.head(10)
# Out:
# 0
# Empty DataFrame
# Columns: [text, label, text_clean, length_text, length_text_clean]
# Index: []

# %%
filtered_df_max = df[df['length_text_clean'] > 6000]

# Print the filtered data
print(len(filtered_df_max))
filtered_df_max.head(10)
# Out:
# 0
# Empty DataFrame
# Columns: [text, label, text_clean, length_text, length_text_clean]
# Index: []

# %%
# Filter rows based on length of text_clean column
df = df[(df['length_text_clean'] <= 6000) & (df['length_text_clean'] >= 30)]
print(df.info())
print("")
print(df.label.value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21904 entries, 0 to 21909
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               21904 non-null  object
#  1   label              21904 non-null  int64
#  2   text_clean         21904 non-null  object
#  3   length_text        21904 non-null  int64
#  4   length_text_clean  21904 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.0+ MB
# None
#
# label
# 1    10957
# 0    10947
# Name: count, dtype: int64

# %%
# calculate minimum and maximum lengths
min_length = df["length_text_clean"].min()
max_length = df["length_text_clean"].max()

print("Shortest text length:", min_length)
print("Longest text length:", max_length)

mean = df['length_text_clean'].mean()
std = df['length_text_clean'].std()
print("Mean", mean)

# Generate a normal distribution with the same mean and standard deviation
normal_distribution = np.random.normal(mean, std, len(df))

# Convert the normal distribution to a range of lengths from min_length to max_length
converted_distribution = np.floor(normal_distribution * max_length / np.max(normal_distribution))

# Plot the data in a histogram
plt.hist(converted_distribution)
plt.xlabel('Length of Text')
plt.ylabel('Count')
plt.title('Distribution of Text Lengths')
plt.show()
# Out:
# Shortest text length: 30
# Longest text length: 4904
# Mean 551.6834824689554

# %%
df.columns
# Out:
# Index(['text', 'label', 'text_clean', 'length_text', 'length_text_clean'], dtype='object')

# %%
# Replace the 'text' column with 'text_clean'
df['text'] = df['text_clean']

# Drop the irrelevant columns
df = df.drop(['text_clean','length_text', 'length_text_clean'], axis=1)

print(df.info())
print("")
print(df.label.value_counts())
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21904 entries, 0 to 21909
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    21904 non-null  object
#  1   label   21904 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 513.4+ KB
# None
#
# label
# 1    10957
# 0    10947
# Name: count, dtype: int64
#                                                 text  label
# 0  মানসিক শারীরিকভাবে অসুস্থ ক্লান্ত পুরো জীবন শা...      1
# 1  দয়া সাথে থাকুন অত্যন্ত দীর্ঘ আপনাকে পড়তে উত্...      1
# 2  জানতাম সাথে ভুল লোক খারাপ জীবন কাটিয়েছে সম্পূ...      1
# 3  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 4  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 5  প্রথমে আপনাকে প্রশ্ন উপস্থাপন যাচ্ছি পারবেন দি...      1
# 6  রেফারেন্সের বয়সী পুরুষ থাকার সাইক ওয়ার্ড বের...      1
# 7  দৈর্ঘ্যের ক্ষমাপ্রার্থী বোঝানোর বের আলিঙ্গন বল...      1
# 8  উপকারী সাব দয়া আপলোড পোস্ট সেরা জায়গা মোবাইল...      1
# 9  দীর্ঘ পোস্ট জীবনের সারসংক্ষেপ টাইম লাইনটি একটু...      1

# %%
# Find the number of samples in label class
class_counts = df['label'].value_counts()

# Determine the majority and minority classes
majority_class = class_counts.idxmax()
minority_class = class_counts.idxmin()

# Calculate the difference between the number of samples in the majority and minority classes
class_diff = class_counts[majority_class] - class_counts[minority_class]

# If the difference is positive, we need to remove samples from the majority class
if class_diff > 0:
    # Get the indices of the majority class samples
    majority_indices = df[df['label'] == majority_class].index

    # Randomly sample from the majority class indices to remove
    remove_indices = np.random.choice(majority_indices, size=class_diff, replace=False)

    # Drop the samples with the selected indices
    df = df.drop(remove_indices)

# If the difference is negative, we need to remove samples from the minority class
elif class_diff < 0:
    # Get the indices of the minority class samples
    minority_indices = df[df['label'] == minority_class].index

    # Randomly sample from the minority class indices to remove
    remove_indices = np.random.choice(minority_indices, size=-class_diff, replace=False)

    # Drop the samples with the selected indices
    df = df.drop(remove_indices)

print(df.info())
print("")
print(df.label.value_counts())
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21894 entries, 0 to 21909
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    21894 non-null  object
#  1   label   21894 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 513.1+ KB
# None
#
# label
# 1    10947
# 0    10947
# Name: count, dtype: int64
#                                                 text  label
# 0  মানসিক শারীরিকভাবে অসুস্থ ক্লান্ত পুরো জীবন শা...      1
# 1  দয়া সাথে থাকুন অত্যন্ত দীর্ঘ আপনাকে পড়তে উত্...      1
# 2  জানতাম সাথে ভুল লোক খারাপ জীবন কাটিয়েছে সম্পূ...      1
# 3  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 4  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 5  প্রথমে আপনাকে প্রশ্ন উপস্থাপন যাচ্ছি পারবেন দি...      1
# 6  রেফারেন্সের বয়সী পুরুষ থাকার সাইক ওয়ার্ড বের...      1
# 7  দৈর্ঘ্যের ক্ষমাপ্রার্থী বোঝানোর বের আলিঙ্গন বল...      1
# 8  উপকারী সাব দয়া আপলোড পোস্ট সেরা জায়গা মোবাইল...      1
# 9  দীর্ঘ পোস্ট জীবনের সারসংক্ষেপ টাইম লাইনটি একটু...      1

# %%
# save the updated DataFrame to a new excel file
df.to_excel('1. Depression Analysis Dataset Cleaned v2.xlsx', index=False)

# %%
df = pd.read_excel('/content/1. Depression Analysis Dataset Cleaned v2.xlsx')

print(df.info())
print("")
print(df.label.value_counts())
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21894 entries, 0 to 21893
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    21894 non-null  object
#  1   label   21894 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 342.2+ KB
# None
#
# label
# 1    10947
# 0    10947
# Name: count, dtype: int64
#                                                 text  label
# 0  মানসিক শারীরিকভাবে অসুস্থ ক্লান্ত পুরো জীবন শা...      1
# 1  দয়া সাথে থাকুন অত্যন্ত দীর্ঘ আপনাকে পড়তে উত্...      1
# 2  জানতাম সাথে ভুল লোক খারাপ জীবন কাটিয়েছে সম্পূ...      1
# 3  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 4  অনেটিভ ইংরেজি স্পিকারের অনুসরণ বিরক্তিকর অপ্রত...      1
# 5  প্রথমে আপনাকে প্রশ্ন উপস্থাপন যাচ্ছি পারবেন দি...      1
# 6  রেফারেন্সের বয়সী পুরুষ থাকার সাইক ওয়ার্ড বের...      1
# 7  দৈর্ঘ্যের ক্ষমাপ্রার্থী বোঝানোর বের আলিঙ্গন বল...      1
# 8  উপকারী সাব দয়া আপলোড পোস্ট সেরা জায়গা মোবাইল...      1
# 9  দীর্ঘ পোস্ট জীবনের সারসংক্ষেপ টাইম লাইনটি একটু...      1

# %% [markdown]
# # Train Test Split

# %%
# Load data
df = pd.read_excel('1. Depression Analysis Dataset Cleaned v2.xlsx')

# %%
# shuffle the rows
df = df.sample(frac=1)
df.head(10)
# Out:
#                                                     text  label
# 17518  আগামীকাল জন্মদিন আমিদুঃখিত বোধ করছি কীভাবে দুঃ...      0
# 8669   ইউনিভার্সিটির মেয়েদের কিভাবে ডিএম প্রসঙ্গে বয...      0
# 10450  আত্মবিশ্বাসী হাসিখুশি মানুষ ছিলাম বিশ্রী ব্যক্...      1
# 4345   সাহায্যের কান্নাকাটি সহানুভূতির পোস্ট অনুভব কর...      1
# 14800  বেপরোয়া চাই মরিয়া আক্ষরিক অর্থেই আপনাকে হতাশ...      0
# 14286  আত্মঘাতী মরতে চাই হাল ছেড়ে চাই মরিয়া শেষ থ্র...      1
# 1938   হাই স্কুল ছেড়ে দিচ্ছি হ্যাঁ শ্রেণীর সেমিস্টার...      0
# 3463   বন্ধুরা সাহায্য করুন যাচ্ছি মাস আক্ষরিক অর্থে ...      0
# 57     সপ্তাহের পোস্ট দেখেছেন টিএল ডিআর কিছুক্ষণের আত...      1
# 1723   জীবন চুষে খুশি নিজেকে যৌনসঙ্গম হত্যা মনেধীরে ধ...      1

# %%
X = df['text']
y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train)

# %%
(unique, counts) = np.unique(y_train, return_counts=True)
np.asarray((unique, counts)).T
# Out:
# array([[   0, 7881],
#        [   1, 7882]])

# %% [markdown]
# # Naive Bayes baseline model

# %%
clf = CountVectorizer()
X_train_cv =  clf.fit_transform(X_train)
X_test_cv = clf.transform(X_test)

# %%
tf_transformer = TfidfTransformer(use_idf=True).fit(X_train_cv)
X_train_tf = tf_transformer.transform(X_train_cv)
X_test_tf = tf_transformer.transform(X_test_cv)

# %%
nb_clf = MultinomialNB()

# %%
nb_clf.fit(X_train_tf, y_train)
# Out:
# MultinomialNB()

# %%
nb_pred = nb_clf.predict(X_test_tf)

# %%
label = ['0', '1']

# %%
print('Classification Report for Naive Bayes:\n',classification_report(y_test, nb_pred, target_names=label))
# Out:
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.84      0.77      0.81      2190
#            1       0.79      0.86      0.82      2189
#
#     accuracy                           0.81      4379
#    macro avg       0.82      0.81      0.81      4379
# weighted avg       0.82      0.81      0.81      4379

# %%
perf_matrix(y_test, nb_pred)
conf_matrix(y_test, nb_pred, 'Naive Bayes Sentiment Analysis\nConfusion Matrix', label)
# Out:
# Accuracy: 0.8134277232244804
# Precision: 0.8156849953270715
# Recall: 0.8134277232244804
# F1 Score: 0.8130959401487936

# %% [markdown]
# # Data preprocessing for LSTM

# %%
def Tokenize(column, seq_len):
    ##Create vocabulary of words from column
    corpus = [word for text in column for word in text.split()]
    count_words = Counter(corpus)
    sorted_words = count_words.most_common()
    vocab_to_int = {w:i+1 for i, (w,c) in enumerate(sorted_words)}

    ##Tokenize the columns text using the vocabulary
    text_int = []
    for text in column:
        r = [vocab_to_int[word] for word in text.split()]
        text_int.append(r)
    ##Add padding to tokens
    features = np.zeros((len(text_int), seq_len), dtype = int)
    for i, review in enumerate(text_int):
        if len(review) <= seq_len:
            zeros = list(np.zeros(seq_len - len(review)))
            new = zeros + review
        else:
            new = review[: seq_len]
        features[i, :] = np.array(new)

    return sorted_words, features

# %%
max_len = 5000

# %%
vocabulary, tokenized_column = Tokenize(df["text"], max_len)

# %%
vocabulary[:20]
# Out:
# [('সাথে', 29452),
#  ('চাই', 19769),
#  ('করেছি', 16421),
#  ('কথা', 13848),
#  ('জানি', 13218),
#  ('করছি', 12980),
#  ('সত্যিই', 11547),
#  ('সম্পর্কে', 9933),
#  ('খারাপ', 9899),
#  ('নিজেকে', 9819),
#  ('সময়', 9729),
#  ('ভাল', 9514),
#  ('অনুভব', 8429),
#  ('শেষ', 8173),
#  ('ছিলাম', 8000),
#  ('সাহায্য', 7339),
#  ('বন্ধু', 7089),
#  ('জীবন', 7087),
#  ('বোধ', 7023),
#  ('পছন্দ', 5720)]

# %%
len(vocabulary)
# Out:
# 61225

# %%
"""
keys = []
values = []
for key, value in vocabulary[:20]:
    keys.append(key)
    values.append(value)

plt.figure(figsize=(15, 5))
# create barplot
ax = sns.barplot(x=keys, y=values, palette='mako')

# set labels
ax.set(xlabel='Keys', ylabel='Values')

plt.title('Top 20 most common words', size=25)
ax.bar_label(ax.containers[0])
plt.ylabel("Words count")
plt.show()
"""
# Out:
# '\nkeys = []\nvalues = []\nfor key, value in vocabulary[:20]:\n    keys.append(key)\n    values.append(value)\n\nplt.figure(figsize=(15, 5))\n# create barplot\nax = sns.barplot(x=keys, y=values, palette=\'mako\')\n\n# set labels\nax.set(xlabel=\'Keys\', ylabel=\'Values\')\n\nplt.title(\'Top 20 most common words\', size=25)\nax.bar_label(ax.containers[0])\nplt.ylabel("Words count")\nplt.show()\n'

# %%
tokenized_column[3:6]
# Out:
# array([[   0,    0,    0, ...,   96,  134,    2],
#        [   0,    0,    0, ...,  223, 1974, 2454],
#        [   0,    0,    0, ..., 9247,  636,  403]])

# %%
df["text"].iloc[10]
# Out:
# 'বোকা দেড় মিনিব্রেকে থাকার কারণে সাথে কথা বলিনি তাড়াতাড়ি শেষ সিনেমা চাই সম্পর্কে সঙ্গী দুঃখ পেতে যোগাযোগ সমস্যা সাথে পুরোপুরি আক্ষরিক অর্থে সাথে নিজেকে প্রকাশ পারিনি দম্পতি ছিলাম একাকী বোধ করিনি কেবল বিরক্ত বোধ করিনি জানতাম কতটা ভাল বলার সম্পর্কে যত্ন অনুভূতি বেশিরভাগ চিন্তাই কেবল কথা বলছি বলছি করছি কথা বলার দরকার'

# %%
tokenized_column[10]
# Out:
# array([ 0,  0,  0, ...,  4, 72, 96])

# %% [markdown]
# # Word Embedding by Word2Vec

# %%
Word2vec_train_data = list(map(lambda x: x.split(), X_train))

# %%
EMBEDDING_DIM = 200

# %%
word2vec_model = Word2Vec(Word2vec_train_data, vector_size=EMBEDDING_DIM)

# %%
print(f"Vocabulary size: {len(vocabulary) + 1}")
# Out:
# Vocabulary size: 61226

# %%
VOCAB_SIZE = len(vocabulary) + 1 #+1 for the padding
VOCAB_SIZE
# Out:
# 61226

# %%
#define empty embedding matrix
embedding_matrix = np.zeros((VOCAB_SIZE, EMBEDDING_DIM))

#fill the embedding matrix with the pre trained values from word2vec
#    corresponding to word (string), token (number associated to the word)
for word, token in vocabulary:
    if word2vec_model.wv.__contains__(word):
        embedding_matrix[token] = word2vec_model.wv.__getitem__(word)

print("Embedding Matrix Shape:", embedding_matrix.shape)
# Out:
# Embedding Matrix Shape: (61226, 200)

# %% [markdown]
# ## Train - Validation - Test split

# %%
df.head(10)
# Out:
#                                                     text  label
# 17518  আগামীকাল জন্মদিন আমিদুঃখিত বোধ করছি কীভাবে দুঃ...      0
# 8669   ইউনিভার্সিটির মেয়েদের কিভাবে ডিএম প্রসঙ্গে বয...      0
# 10450  আত্মবিশ্বাসী হাসিখুশি মানুষ ছিলাম বিশ্রী ব্যক্...      1
# 4345   সাহায্যের কান্নাকাটি সহানুভূতির পোস্ট অনুভব কর...      1
# 14800  বেপরোয়া চাই মরিয়া আক্ষরিক অর্থেই আপনাকে হতাশ...      0
# 14286  আত্মঘাতী মরতে চাই হাল ছেড়ে চাই মরিয়া শেষ থ্র...      1
# 1938   হাই স্কুল ছেড়ে দিচ্ছি হ্যাঁ শ্রেণীর সেমিস্টার...      0
# 3463   বন্ধুরা সাহায্য করুন যাচ্ছি মাস আক্ষরিক অর্থে ...      0
# 57     সপ্তাহের পোস্ট দেখেছেন টিএল ডিআর কিছুক্ষণের আত...      1
# 1723   জীবন চুষে খুশি নিজেকে যৌনসঙ্গম হত্যা মনেধীরে ধ...      1

# %%
X = tokenized_column
y = df['label'].values
y
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train)

# %%
(unique, counts) = np.unique(y_train, return_counts=True)
np.asarray((unique, counts)).T
# Out:
# array([[   0, 7882],
#        [   1, 7881]])

# %% [markdown]
# # PyTorch datasets and dataloaders

# %%
BATCH_SIZE = 8
EPOCHS = 5 #Number of training epoch
LR = 0.003 #Learning rate
DROPOUT = 0.5 #LSTM Dropout
WEIGHT_DECAY = 0.001
LSTM_LAYERS = 1 #Number of stacked LSTM layers
HIDDEN_DIM = 100 #number of neurons of the internal state (internal neural network in the LSTM)

NUM_CLASSES = 2 #We are dealing with a multiclass classification of 2 classes
BIDIRECTIONAL = False #Boolean value to choose if to use a bidirectional LSTM or not

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
train_data = TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train))
test_data = TensorDataset(torch.from_numpy(X_test), torch.from_numpy(y_test))
valid_data = TensorDataset(torch.from_numpy(X_valid), torch.from_numpy(y_valid))

# %%
train_loader = DataLoader(train_data, shuffle=True, batch_size=BATCH_SIZE, drop_last=True)
valid_loader = DataLoader(valid_data, shuffle=True, batch_size=BATCH_SIZE, drop_last=True)
test_loader = DataLoader(test_data, shuffle=True, batch_size=BATCH_SIZE, drop_last=True)

# %% [markdown]
# ## PyTorch LSTM modeling

# %%
class LSTM_Sentiment_Classifier(nn.Module):

    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_classes, lstm_layers, bidirectional,batch_size, dropout):
        super(LSTM_Sentiment_Classifier,self).__init__()

        self.lstm_layers = lstm_layers
        self.num_directions = 2 if bidirectional else 1
        self.hidden_dim = hidden_dim
        self.num_classes = num_classes
        self.batch_size = batch_size


        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        self.lstm = nn.LSTM(embedding_dim,
                            hidden_dim,
                            num_layers=lstm_layers,
                            dropout=dropout,
                            bidirectional=bidirectional,
                            batch_first=True)

        self.fc = nn.Linear(hidden_dim*self.num_directions, num_classes)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, x, hidden):
        self.batch_size = x.size(0)
        ##EMBEDDING LAYER
        embedded = self.embedding(x)
        #LSTM LAYERS
        out, hidden = self.lstm(embedded, hidden)
        #Extract only the hidden state from the last LSTM cell
        out = out[:,-1,:]
        #FULLY CONNECTED LAYERS
        out = self.fc(out)
        out = self.softmax(out)

        return out, hidden

    def init_hidden(self, batch_size):
        #Initialization of the LSTM hidden and cell states
        h0 = torch.zeros((self.lstm_layers*self.num_directions, batch_size, self.hidden_dim)).detach().to(DEVICE)
        c0 = torch.zeros((self.lstm_layers*self.num_directions, batch_size, self.hidden_dim)).detach().to(DEVICE)
        hidden = (h0, c0)
        return hidden

# %%
model = LSTM_Sentiment_Classifier(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM,NUM_CLASSES, LSTM_LAYERS,BIDIRECTIONAL, BATCH_SIZE, DROPOUT)
model = model.to(DEVICE)

#Initialize embedding with the previously defined embedding matrix
model.embedding.weight.data.copy_(torch.from_numpy(embedding_matrix))
#Allow the embedding matrix to be fined tuned to better adapt to out dataset and get higher accuracy
model.embedding.weight.requires_grad=True

print(model)
# Out:
# LSTM_Sentiment_Classifier(
#   (embedding): Embedding(61226, 200)
#   (lstm): LSTM(200, 100, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=100, out_features=2, bias=True)
#   (softmax): LogSoftmax(dim=1)
# )

# %%
criterion = nn.NLLLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay = WEIGHT_DECAY)

# %% [markdown]
# ### LSTM Training loop

# %%
total_step = len(train_loader)
total_step_val = len(valid_loader)

early_stopping_patience = 4
early_stopping_counter = 0

valid_acc_max = 0 # Initialize best accuracy top 0

for e in range(EPOCHS):

    #lists to host the train and validation losses of every batch for each epoch
    train_loss, valid_loss  = [], []
    #lists to host the train and validation accuracy of every batch for each epoch
    train_acc, valid_acc  = [], []

    #lists to host the train and validation predictions of every batch for each epoch
    y_train_list, y_val_list = [], []

    #initalize number of total and correctly classified texts during training and validation
    correct, correct_val = 0, 0
    total, total_val = 0, 0
    running_loss, running_loss_val = 0, 0


    ####TRAINING LOOP####

    model.train()

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE) #load features and targets in device

        h = model.init_hidden(labels.size(0))

        model.zero_grad() #reset gradients

        output, h = model(inputs,h) #get output and hidden states from LSTM network

        loss = criterion(output, labels)
        loss.backward()

        running_loss += loss.item()

        optimizer.step()

        y_pred_train = torch.argmax(output, dim=1) #get tensor of predicted values on the training set
        y_train_list.extend(y_pred_train.squeeze().tolist()) #transform tensor to list and the values to the list

        correct += torch.sum(y_pred_train==labels).item() #count correctly classified texts per batch
        total += labels.size(0) #count total texts per batch

    train_loss.append(running_loss / total_step)
    train_acc.append(100 * correct / total)

    ####VALIDATION LOOP####

    with torch.no_grad():

        model.eval()

        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

            val_h = model.init_hidden(labels.size(0))

            output, val_h = model(inputs, val_h)

            val_loss = criterion(output, labels)
            running_loss_val += val_loss.item()

            y_pred_val = torch.argmax(output, dim=1)
            y_val_list.extend(y_pred_val.squeeze().tolist())

            correct_val += torch.sum(y_pred_val==labels).item()
            total_val += labels.size(0)

        valid_loss.append(running_loss_val / total_step_val)
        valid_acc.append(100 * correct_val / total_val)

    #Save model if validation accuracy increases
    if np.mean(valid_acc) >= valid_acc_max:
        torch.save(model.state_dict(), './state_dict.pt')
        print(f'Epoch {e+1}:Validation accuracy increased ({valid_acc_max:.6f} --> {np.mean(valid_acc):.6f}).  Saving model ...')
        valid_acc_max = np.mean(valid_acc)
        early_stopping_counter=0 #reset counter if validation accuracy increases
    else:
        print(f'Epoch {e+1}:Validation accuracy did not increase')
        early_stopping_counter+=1 #increase counter if validation accuracy does not increase

    if early_stopping_counter > early_stopping_patience:
        print('Early stopped at epoch :', e+1)
        break

    print(f'\tTrain_loss : {np.mean(train_loss):.4f} Val_loss : {np.mean(valid_loss):.4f}')
    print(f'\tTrain_acc : {np.mean(train_acc):.3f}% Val_acc : {np.mean(valid_acc):.3f}%')
# Out:
# Epoch 1:Validation accuracy increased (0.000000 --> 88.356164).  Saving model ...
# 	Train_loss : 0.3871 Val_loss : 0.3102
# 	Train_acc : 82.576% Val_acc : 88.356%
# Epoch 2:Validation accuracy did not increase
# 	Train_loss : 0.1595 Val_loss : 0.3421
# 	Train_acc : 94.296% Val_acc : 88.299%
# Epoch 3:Validation accuracy did not increase
# 	Train_loss : 0.0702 Val_loss : 0.4543
# 	Train_acc : 97.595% Val_acc : 85.502%
# Epoch 4:Validation accuracy did not increase
# 	Train_loss : 0.0334 Val_loss : 0.5771
# 	Train_acc : 98.858% Val_acc : 85.046%
# Epoch 5:Validation accuracy did not increase
# 	Train_loss : 0.0175 Val_loss : 0.6369
# 	Train_acc : 99.410% Val_acc : 85.616%

# %%
# Loading the best model
model.load_state_dict(torch.load('./state_dict.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### LSTM Testing

# %%
model.eval()
y_pred_list = []
y_test_list = []
for inputs, labels in test_loader:
    inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
    test_h = model.init_hidden(labels.size(0))

    output, val_h = model(inputs, test_h)
    y_pred_test = torch.argmax(output, dim=1)
    y_pred_list.extend(y_pred_test.squeeze().tolist())
    y_test_list.extend(labels.squeeze().tolist())

# %%
label = ['0', '1']

# %%
print('Classification Report for LSTM :\n', classification_report(y_test_list, y_pred_list, target_names=label))
# Out:
# Classification Report for LSTM :
#                precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      2188
#            1       0.89      0.89      0.89      2188
#
#     accuracy                           0.89      4376
#    macro avg       0.89      0.89      0.89      4376
# weighted avg       0.89      0.89      0.89      4376

# %%
perf_matrix(y_test_list, y_pred_list)
conf_matrix(y_test_list,y_pred_list,'PyTorch LSTM Sentiment Analysis\nConfusion Matrix', label)
# Out:
# Accuracy: 0.8887111517367459
# Precision: 0.8887151303606734
# Recall: 0.8887111517367459
# F1 Score: 0.8887108669667607

# %% [markdown]
# ## PyTorch BiLSTM modeling

# %%
NUM_CLASSES = 2 #We are dealing with a multiclass classification of 2 classes
BIDIRECTIONAL = True #Boolean value to choose if to use a bidirectional LSTM or not

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class BiLSTM_Sentiment_Classifier(nn.Module):

    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_classes, lstm_layers, bidirectional,batch_size, dropout):
        super(BiLSTM_Sentiment_Classifier,self).__init__()

        self.lstm_layers = lstm_layers
        self.num_directions = 2 if bidirectional else 1
        self.hidden_dim = hidden_dim
        self.num_classes = num_classes
        self.batch_size = batch_size


        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        self.lstm = nn.LSTM(embedding_dim,
                            hidden_dim,
                            num_layers=lstm_layers,
                            dropout=dropout,
                            bidirectional=bidirectional,
                            batch_first=True)

        self.fc = nn.Linear(hidden_dim*self.num_directions, num_classes)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, x, hidden):
        self.batch_size = x.size(0)
        ##EMBEDDING LAYER
        embedded = self.embedding(x)
        #LSTM LAYERS
        out, hidden = self.lstm(embedded, hidden)
        #Extract only the hidden state from the last LSTM cell
        out = out[:,-1,:]
        #FULLY CONNECTED LAYERS
        out = self.fc(out)
        out = self.softmax(out)

        return out, hidden

    def init_hidden(self, batch_size):
        #Initialization of the LSTM hidden and cell states
        h0 = torch.zeros((self.lstm_layers*self.num_directions, batch_size, self.hidden_dim)).detach().to(DEVICE)
        c0 = torch.zeros((self.lstm_layers*self.num_directions, batch_size, self.hidden_dim)).detach().to(DEVICE)
        hidden = (h0, c0)
        return hidden

# %%
model = BiLSTM_Sentiment_Classifier(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM,NUM_CLASSES, LSTM_LAYERS,BIDIRECTIONAL, BATCH_SIZE, DROPOUT)
model = model.to(DEVICE)

#Initialize embedding with the previously defined embedding matrix
model.embedding.weight.data.copy_(torch.from_numpy(embedding_matrix))
#Allow the embedding matrix to be fined tuned to better adapt to out dataset and get higher accuracy
model.embedding.weight.requires_grad=True

print(model)
# Out:
# BiLSTM_Sentiment_Classifier(
#   (embedding): Embedding(61226, 200)
#   (lstm): LSTM(200, 100, batch_first=True, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=200, out_features=2, bias=True)
#   (softmax): LogSoftmax(dim=1)
# )

# %%
criterion = nn.NLLLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay = WEIGHT_DECAY)

# %% [markdown]
# ### BiLSTM Training loop

# %%
total_step = len(train_loader)
total_step_val = len(valid_loader)

early_stopping_patience = 4
early_stopping_counter = 0

valid_acc_max = 0 # Initialize best accuracy top 0

for e in range(EPOCHS):

    #lists to host the train and validation losses of every batch for each epoch
    train_loss, valid_loss  = [], []
    #lists to host the train and validation accuracy of every batch for each epoch
    train_acc, valid_acc  = [], []

    #lists to host the train and validation predictions of every batch for each epoch
    y_train_list, y_val_list = [], []

    #initalize number of total and correctly classified texts during training and validation
    correct, correct_val = 0, 0
    total, total_val = 0, 0
    running_loss, running_loss_val = 0, 0


    ####TRAINING LOOP####

    model.train()

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE) #load features and targets in device

        h = model.init_hidden(labels.size(0))

        model.zero_grad() #reset gradients

        output, h = model(inputs,h) #get output and hidden states from LSTM network

        loss = criterion(output, labels)
        loss.backward()

        running_loss += loss.item()

        optimizer.step()

        y_pred_train = torch.argmax(output, dim=1) #get tensor of predicted values on the training set
        y_train_list.extend(y_pred_train.squeeze().tolist()) #transform tensor to list and the values to the list

        correct += torch.sum(y_pred_train==labels).item() #count correctly classified texts per batch
        total += labels.size(0) #count total texts per batch

    train_loss.append(running_loss / total_step)
    train_acc.append(100 * correct / total)

    ####VALIDATION LOOP####

    with torch.no_grad():

        model.eval()

        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

            val_h = model.init_hidden(labels.size(0))

            output, val_h = model(inputs, val_h)

            val_loss = criterion(output, labels)
            running_loss_val += val_loss.item()

            y_pred_val = torch.argmax(output, dim=1)
            y_val_list.extend(y_pred_val.squeeze().tolist())

            correct_val += torch.sum(y_pred_val==labels).item()
            total_val += labels.size(0)

        valid_loss.append(running_loss_val / total_step_val)
        valid_acc.append(100 * correct_val / total_val)

    #Save model if validation accuracy increases
    if np.mean(valid_acc) >= valid_acc_max:
        torch.save(model.state_dict(), './state_dict.pt')
        print(f'Epoch {e+1}:Validation accuracy increased ({valid_acc_max:.6f} --> {np.mean(valid_acc):.6f}).  Saving model ...')
        valid_acc_max = np.mean(valid_acc)
        early_stopping_counter=0 #reset counter if validation accuracy increases
    else:
        print(f'Epoch {e+1}:Validation accuracy did not increase')
        early_stopping_counter+=1 #increase counter if validation accuracy does not increase

    if early_stopping_counter > early_stopping_patience:
        print('Early stopped at epoch :', e+1)
        break

    print(f'\tTrain_loss : {np.mean(train_loss):.4f} Val_loss : {np.mean(valid_loss):.4f}')
    print(f'\tTrain_acc : {np.mean(train_acc):.3f}% Val_acc : {np.mean(valid_acc):.3f}%')
# Out:
# Epoch 1:Validation accuracy increased (0.000000 --> 87.785388).  Saving model ...
# 	Train_loss : 0.4070 Val_loss : 0.2939
# 	Train_acc : 81.396% Val_acc : 87.785%
# Epoch 2:Validation accuracy did not increase
# 	Train_loss : 0.1685 Val_loss : 0.3166
# 	Train_acc : 93.890% Val_acc : 86.473%
# Epoch 3:Validation accuracy did not increase
# 	Train_loss : 0.0741 Val_loss : 0.3657
# 	Train_acc : 97.589% Val_acc : 87.557%
# Epoch 4:Validation accuracy did not increase
# 	Train_loss : 0.0364 Val_loss : 0.5383
# 	Train_acc : 98.826% Val_acc : 86.929%
# Epoch 5:Validation accuracy did not increase
# 	Train_loss : 0.0183 Val_loss : 0.5867
# 	Train_acc : 99.404% Val_acc : 86.244%

# %%
# Loading the best model
model.load_state_dict(torch.load('./state_dict.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### BiLSTM Testing

# %%
model.eval()
y_pred_list = []
y_test_list = []
for inputs, labels in test_loader:
    inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
    test_h = model.init_hidden(labels.size(0))

    output, val_h = model(inputs, test_h)
    y_pred_test = torch.argmax(output, dim=1)
    y_pred_list.extend(y_pred_test.squeeze().tolist())
    y_test_list.extend(labels.squeeze().tolist())

# %%
label = ['0','1']

# %%
print('Classification Report for Bi-LSTM :\n', classification_report(y_test_list, y_pred_list, target_names=label))
# Out:
# Classification Report for Bi-LSTM :
#                precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88      1792
#            1       0.87      0.91      0.89      1792
#
#     accuracy                           0.88      3584
#    macro avg       0.88      0.88      0.88      3584
# weighted avg       0.88      0.88      0.88      3584

# %%
perf_matrix(y_test_list, y_pred_list)
# conf_matrix(y_test_list,y_pred_list,'PyTorch Bi-LSTM Sentiment Analysis\nConfusion Matrix', label)
# Out:
# Accuracy: 0.8842075892857143
# Precision: 0.8849941788677453
# Recall: 0.8842075892857143
# F1 Score: 0.8841484145922086

# %% [markdown]
# # Bayesian Optimization
